# %% [markdown]
# ## Uniform distribution

# %%
#A uniform distribution is the one for which the values have the same probability
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#Where we import the numpy for doing the computations, and matplotlib for the graphical representations

a = 1
b = 100
n = 200
#The values we are going to make for the uniform distribution

data = np.random.uniform(a,b,n)
#Where a is the initial value it can take, the b is the end of the interval. N is the number of values we get.

# %matplotlib inline
plt.hist(data)
#Plotting an histogram
# Out:
# (array([23., 21., 21., 22., 17., 21., 20., 18., 19., 18.]),
#  array([ 1.75537198, 11.44726906, 21.13916615, 30.83106323, 40.52296031,
#         50.2148574 , 59.90675448, 69.59865157, 79.29054865, 88.98244573,
#         98.67434282]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Normal distribution

# %%
#We are going to use randn to create the normal distribution (the standard one has mean 0 and sd of 1)
n=100

data = np.random.randn(n)

x = range(1,101)
#X must have same first dimensions as in n

plt.plot(x, data)
#We will plot the different values we have obtained

# %%
#Creating a non-standard normal distribution
mu = 5.5
sd = 2.5
z_values = np.random.randn(n)
#Will have a mean of 5.5, and a standard deviation of 5.5

data = mu + sd * z_values

# %matplotlib inline
plt.hist(data)
# Out:
# (array([ 3.,  8., 14., 18., 21., 18.,  9.,  5.,  2.,  2.]),
#  array([-0.40486894,  0.92190554,  2.24868001,  3.57545448,  4.90222896,
#          6.22900343,  7.55577791,  8.88255238, 10.20932686, 11.53610133,
#         12.86287581]),
#  <BarContainer object of 10 artists>)

# %%
#How randn works
np.random.randn(2,5)

#First number is going to create a the number of normal distributions
#The second one is how much values each normal distribution will have
# Out:
# array([[ 0.79013451, -1.58707239,  0.76128986, -1.12805057, -2.19796367],
#        [ 1.46959794,  0.51009325, -0.19318988,  0.26919546,  0.0970115 ]])

# %% [markdown]
# ## Montecarlo Method

# %% [markdown]
# * The Montecarlo Method is a way to compute the number py probabilities
# * If we have a circle of r inside of a box of 2r, the probability of a point being inside of the circle is pi/4

# %%
def montecarlo(n, n_exp):
    pi_avg = 0
    pi_value_list = []
    
    for i in range(n_exp):
        value = 0
        x = np.random.uniform(0,1,n).tolist()
        y = np.random.uniform(0,1,n).tolist()
        
        for j in range(n):
            z = np.sqrt(x[j] * x[j] + y[j] * y[j])
            if z<= i:
                value += 1 #Representing is inside the circle
        float_value = float(value)
        pi_value = float_value * 4 / n #We have to multiply by 4 to get pi
        pi_value_list.append(pi_value)
        pi_avg += pi_value
        
    pi = pi_avg/n_exp
    
    print(pi)
    plt.plot(pi_value_list)
    
montecarlo(1000,100)
# Out:
# 3.95048

# %% [markdown]
# ## Dummy dataset

# %%
#We could create a dummy dataset: a dataset with random numbers of length n
n=10

data = pd.DataFrame(
    {
        'Column 1': np.random.randn(n),
        'Column 2': 5.5 + 2.5 * np.random.randn(n),
        'Column 3': np.random.uniform(0,1,n)
    }
)

data.head()
# Out:
#    Column 1  Column 2  Column 3
# 0  0.399978  8.939765  0.289221
# 1  1.103309  4.423010  0.011051
# 2  2.078192  4.250377  0.541065
# 3 -0.658008  7.824717  0.695440
# 4 -0.072196  5.899453  0.752455

# %%
#We could check that the distribution is quite similar
data.describe()
# Out:
#         Column 1   Column 2   Column 3
# count  10.000000  10.000000  10.000000
# mean    0.368842   6.044358   0.549230
# std     1.373386   2.518281   0.236366
# min    -1.469193   2.018960   0.011051
# 25%    -0.511555   4.293535   0.526665
# 50%     0.169646   5.429375   0.615181
# 75%     1.032022   8.037143   0.694448
# max     2.795660   9.851663   0.759365

# %%
mainpath = "C:/Users/Msi/Documents/YO/Programación/Machine Learning/datasets"
filepath = "/customer_churn_model/customer_churn_model.txt"

data = pd.read_csv(mainpath+filepath)
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
#We could create a more complex dummy dataset
new_data = pd.DataFrame
